# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("titles.csv")
df.head()
# Out:
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970
# 3               Machine  2007
# 4                  MARy  2008

# %%
df.shape[0]
# Out:
# 244914

# %%
(df.sort_values(by=['year'])).head(2)
# Out:
#                      title  year
# 193222          Miss Jerry  1894
# 51388   The Startled Lover  1898

# %%
df[df["title"]=="Hamlet"]
# Out:
#          title  year
# 6422    Hamlet  2017
# 10637   Hamlet  1921
# 39916   Hamlet  1913
# 52521   Hamlet  1910
# 62000   Hamlet  2000
# 67406   Hamlet  1969
# 82130   Hamlet  1987
# 88065   Hamlet  2016
# 101728  Hamlet  1948
# 122827  Hamlet  1973
# 133921  Hamlet  1976
# 154029  Hamlet  2015
# 161324  Hamlet  1964
# 172640  Hamlet  1954
# 173033  Hamlet  2011
# 178222  Hamlet  1996
# 189093  Hamlet  2009
# 192142  Hamlet  1990
# 198234  Hamlet  1911
# 202025  Hamlet  2014

# %%
df[df["title"]=="Hamlet"].shape[0]
# Out:
# 20

# %%
df[df["title"]=="North by Northwest"]
# Out:
#                     title  year
# 74398  North by Northwest  1959

# %%
df[df["title"]=="North by Northwest"].shape[0]
# Out:
# 1

# %%
(df[df["title"]=="Hamlet"].sort_values(by=['year'])).head(1)
# Out:
#         title  year
# 52521  Hamlet  1910

# %%
df[df["title"]=="Treasure Island"]
# Out:
#                   title  year
# 27076   Treasure Island  1999
# 37238   Treasure Island  1973
# 55686   Treasure Island  1918
# 65051   Treasure Island  1972
# 77354   Treasure Island  1950
# 141822  Treasure Island  1934
# 173051  Treasure Island  1985
# 196514  Treasure Island  1920

# %%
df[df["year"]==1950].shape[0]
# Out:
# 1113

# %%
df[df["year"]==1960].shape[0]
# Out:
# 1549

# %%
df[df["year"].between(1950,1959)].shape[0]
# Out:
# 12934

# %%
[df[df["title"]=="Batman"].year]
# Out:
# [39349     1943
#  240896    1989
#  Name: year, dtype: int64]

# %%
df1 = pd.read_csv("cast.csv")
df1.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
df1[df1["title"]=='Inception'].shape[0]
# Out:
# 78

# %%
df2=df1[df1["title"]=='Inception']
df2[df2['n'].isna()]
# Out:
#              title  year                     name     type  \
# 98153    Inception  2010     Michael (III) August    actor
# 197877   Inception  2010                 Ken Bhan    actor
# 374661   Inception  2010            John Ceallach    actor
# 497161   Inception  2010             Garvin Cross    actor
# 684098   Inception  2010            Seve Esposito    actor
# 690634   Inception  2010      Marcus (II) Everett    actor
# 707642   Inception  2010  Zachary Christopher Fay    actor
# 836295   Inception  2010        Daniel Girondeaud    actor
# 1006636  Inception  2010          Andrew Hoagland    actor
# 1095095  Inception  2010          Charles Jarrell    actor
# 1108755  Inception  2010            Seong-hwan Jo    actor
# 1120184  Inception  2010          Alonzo F. Jones    actor
# 1189066  Inception  2010               Mobin Khan    actor
# 1248176  Inception  2010            Shunsaku Kud?    actor
# 1296268  Inception  2010         John (IX) Lawson    actor
# ...

# %%
df2[df2['n'].isna()].shape[0]
# Out:
# 27

# %%
df2[df2['n'].notna()].shape[0]
# Out:
# 51

# %%
df2=df1[df1["title"]=='North by Northwest']
df3=df2[df2['n'].notna()]
(df3.sort_values(by=['n']))
# Out:
#                       title  year                  name     type  \
# 871426   North by Northwest  1959            Cary Grant    actor
# 3518333  North by Northwest  1959       Eva Marie Saint  actress
# 1457165  North by Northwest  1959           James Mason    actor
# 3157232  North by Northwest  1959   Jessie Royce Landis  actress
# 356707   North by Northwest  1959        Leo G. Carroll    actor
# 3048272  North by Northwest  1959  Josephine Hutchinson  actress
# 1695173  North by Northwest  1959           Philip Ober    actor
# 1275337  North by Northwest  1959         Martin Landau    actor
# 2447081  North by Northwest  1959         Adam Williams    actor
# 1811387  North by Northwest  1959          Edward Platt    actor
# 665768   North by Northwest  1959     Robert Ellenstein    actor
# 2295714  North by Northwest  1959          Les Tremayne    actor
# 464736   North by Northwest  1959       Philip Coolidge    actor
# ...

# %%
df2=df1[df1["title"]=='Sleuth']
df3=df2[df2["year"]==1972]
(df3.sort_values(by=['n']))
# Out:
#           title  year                name     type  \
# 1705394  Sleuth  1972    Laurence Olivier    actor
# 326773   Sleuth  1972       Michael Caine    actor
# 373876   Sleuth  1972      Alec Cawthorne    actor
# 1465483  Sleuth  1972  John (II) Matthews    actor
# 2724553  Sleuth  1972  Eve (III) Channing  actress
# 1448690  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1705394                 Andrew Wyke  1.0
# 326773                  Milo Tindle  2.0
# 373876            Inspector Doppler  3.0
# 1465483  Detective Sergeant Tarrant  4.0
# 2724553             Marguerite Wyke  5.0
# 1448690      Police Constable Higgs  6.0

# %%
df2=df1[df1["title"]=='Sleuth']
df3=df2[df2["year"]==2007]
(df3.sort_values(by=['n']))
# Out:
#           title  year                 name     type          character    n
# 326774   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1293634  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1805907  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 260242   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 373877   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2724552  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3370424  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %%
df2=df1[df1["title"]=='Hamlet']
df3=df2[df2["year"]==1921]
print(df3)
df3.shape[0]
# Out:
#           title  year                    name     type         character    n
# 7789     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 458904   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 555034   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1135279  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2185558  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2375993  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2664423  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 3062023  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3355176  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0
# 9

# %%
df2=df1[df1["title"]=='Hamlet']
df3=df2[df2["year"]==1996]

df3
# Out:
#           title  year                    name     type  \
# 1731     Hamlet  1996              Riz Abbasi    actor
# 95861    Hamlet  1996    Richard Attenborough    actor
# 158642   Hamlet  1996     Simon Russell Beale    actor
# 214473   Hamlet  1996         David (V) Blair    actor
# 219554   Hamlet  1996           Brian Blessed    actor
# 250773   Hamlet  1996      Christopher Bowles    actor
# 260225   Hamlet  1996         Kenneth Branagh    actor
# 272749   Hamlet  1996          Richard Briers    actor
# 294652   Hamlet  1996          Michael Bryant    actor
# 319501   Hamlet  1996            Peter Bygott    actor
# 344365   Hamlet  1996       Kenneth W Caravan    actor
# 500916   Hamlet  1996           Billy Crystal    actor
# 518572   Hamlet  1996           Charles Daish    actor
# 576147   Hamlet  1996        G?rard Depardieu    actor
# 598618   Hamlet  1996          Reece Dinsdale    actor
# 604339   Hamlet  1996                Ken Dodd    actor
# ...

# %%
df3.shape[0]
# Out:
# 54

# %%
df1[df1["title"]=='Hamlet'].shape[0]
# Out:
# 342

# %%
df2=df1[df1["character"]=='Ophelia']
df2.shape[0]
# Out:
# 117

# %%
df2=df1[df1["character"]=='The Dude']
df2.shape[0]
# Out:
# 19

# %%
df2=df1[df1["character"]=='The Stranger']
df2.shape[0]
# Out:
# 212

# %%
df2=df1[df1["name"]=='Sidney Poitier']
df2.shape[0]
# Out:
# 43

# %%
df2=df1[df1["name"]=='Cary Grant']
df3=df2[df2["year"].between(1940,1950)]
df3[df3["n"]==2]
# Out:
#                    title  year        name   type    character    n
# 871423  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 871433    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %%
df2=df1[df1["name"]=='Cary Grant']
df3=df2[df2["year"].between(1940,1950)]
df3.sort_values(by=['year'])
# Out:
#                                        title  year        name   type  \
# 871450                The Philadelphia Story  1940  Cary Grant  actor
# 871448               The Howards of Virginia  1940  Cary Grant  actor
# 871407                       His Girl Friday  1940  Cary Grant  actor
# 871423                      My Favorite Wife  1940  Cary Grant  actor
# 871438                             Suspicion  1941  Cary Grant  actor
# 871433                        Penny Serenade  1941  Cary Grant  actor
# 871429                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 871452                  The Talk of the Town  1942  Cary Grant  actor
# 871398                     Destination Tokyo  1943  Cary Grant  actor
# 871422                             Mr. Lucky  1943  Cary Grant  actor
# 871390                  Arsenic and Old Lace  1944  Cary Grant  actor
# 871430                      Once Upon a Time  1944  Cary Grant  actor
# ...

# %%
df2=df1[df1["year"].between(1950,1960)]
df2[df2["type"]=='actor'].shape[0]
# Out:
# 171302

# %%
df2=df1[df1["year"].between(1950,1960)]
df2[df2["type"]=='actress'].shape[0]
# Out:
# 63333

# %%
df2=df1[df1['n']==1]
df2[df2['year']<=1980].shape[0]
# Out:
# 65140

# %%
df2=df1[df1['n'].isna()]
df2[df2['year']<=1980].shape[0]
# Out:
# 448347
